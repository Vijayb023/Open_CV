# %%
import cv2
import numpy as np
from dataPath import DATA_PATH
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.image as mpimg

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (6.0, 6.0)
matplotlib.rcParams['image.cmap'] = 'gray'

# %%
image = mpimg.imread("cat.png")

# %%
print(image)
# Out:
# [[[0.17254902 0.19215687 0.21960784]
#   [0.13333334 0.14901961 0.17254902]
#   [0.12156863 0.12941177 0.16470589]
#   ...
#   [0.18039216 0.08627451 0.01176471]
#   [0.17254902 0.07843138 0.00784314]
#   [0.17254902 0.07450981 0.01176471]]
#
#  [[0.1764706  0.1882353  0.21960784]
#   [0.13725491 0.16078432 0.18039216]
#   [0.1254902  0.16078432 0.1882353 ]
#   ...
#   [0.16078432 0.06666667 0.01176471]
#   [0.16470589 0.07450981 0.00784314]
#   [0.1764706  0.08235294 0.00784314]]
#
#  [[0.16470589 0.18431373 0.20784314]
#   [0.12156863 0.14901961 0.16470589]
#   [0.1254902  0.16078432 0.1764706 ]
#   ...
#   [0.16862746 0.07450981 0.00784314]
#   [0.17254902 0.07450981 0.00784314]
#   [0.16078432 0.07058824 0.00784314]]
#
#  ...
#
#  [[0.42745098 0.31764707 0.18039216]
#   [0.38431373 0.27058825 0.12156863]
#   [0.3882353  0.2784314  0.12941177]
#   ...
#   [0.38039216 0.25490198 0.09019608]
#   [0.38039216 0.25882354 0.10196079]
#   [0.38039216 0.25882354 0.09803922]]
#
#  [[0.41960785 0.30588236 0.16862746]
#   [0.38431373 0.27058825 0.12941177]
#   [0.3764706  0.27058825 0.1254902 ]
#   ...
#   [0.40392157 0.26666668 0.10588235]
#   [0.38039216 0.25490198 0.09411765]
#   [0.38431373 0.2627451  0.10196079]]
#
#  [[0.4392157  0.32156864 0.18431373]
#   [0.39215687 0.28235295 0.13725491]
#   [0.40784314 0.2901961  0.13333334]
#   ...
#   [0.38039216 0.2509804  0.10196079]
#   [0.3647059  0.24313726 0.08627451]
#   [0.39607844 0.26666668 0.11372549]]]

# %%
imgplot = plt.imshow(image)

# %%
imageCopy = image.copy()

# %%
emptyMatrix = np.zeros((100,200,3),dtype='uint8')
plt.imshow(emptyMatrix)

# %%
emptyMatrix = 255*np.ones((100,200,3),dtype='uint8')
plt.imshow(emptyMatrix)

# %%
emptyOriginal = 100*np.ones_like(image)
plt.imshow(emptyOriginal)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
imgplot = plt.imshow(image)

# %%
crop = image[110:500,300:800]

# %%
plt.imshow(crop[:,:,::-1])

# %%
copiedImage = image.copy()
plt.imshow(copiedImage[...,::-1])

# %%
copyRoi = image[110:500,300:800]

# Find height and width of the ROI
roiHeight,roiWidth = copyRoi.shape[:2]

# Copy to left of Face
copiedImage[110:110+roiHeight, 10:10+roiWidth] = copyRoi
# Copy to right of Face
copiedImage[110:110+roiHeight, 500:500+roiWidth] = copyRoi

# Display the output
plt.figure(figsize=[15,15])
plt.subplot(121);plt.imshow(image[...,::-1]);plt.title("Original Image");
plt.subplot(122);plt.imshow(copiedImage[...,::-1]);plt.title("Output Image");

# %%
resizeDownWidth = 300
resizeDownHeight = 200
resizedDown = cv2.resize(image, (resizeDownWidth, resizeDownHeight), interpolation= cv2.INTER_LINEAR)

# Mess up with the aspect ratio
resizeUpWidth = 600
resizeUpHeight = 900
resizedUp = cv2.resize(image, (resizeUpWidth, resizeUpHeight), interpolation= cv2.INTER_LINEAR)

plt.figure(figsize=[15,15])
plt.subplot(131);plt.imshow(image[:,:,::-1]);plt.title("Original Image")
plt.subplot(132);plt.imshow(resizedUp[:,:,::-1]);plt.title("Scaled Up Image")
plt.subplot(133);plt.imshow(resizedDown[:,:,::-1]);plt.title("Scaled Down Image")
# Out:
# Text(0.5, 1.0, 'Scaled Down Image')

# %%
mask1 = np.zeros_like(image)
plt.imshow(mask1)

# %%
mask1[110:500,300:800] = 255
plt.figure(figsize=[15,15])
plt.subplot(121);plt.imshow(image[:,:,::-1]);plt.title("Original Image")
plt.subplot(122);plt.imshow(mask1[:,:,::-1]);plt.title("Mask")
print(mask1.dtype)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# float32

# %%
mask2 = cv2.inRange(image, (0,0,150), (100,100,255))
plt.figure(figsize=[15,15])
plt.subplot(121);plt.imshow(image[...,::-1]);plt.title("Original Image")
plt.subplot(122);plt.imshow(mask2);plt.title("Masked Image")
# Out:
# Text(0.5, 1.0, 'Masked Image')
